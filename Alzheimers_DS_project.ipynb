# %% [markdown]
# <a href="https://colab.research.google.com/github/nargisk16/Alzheimer-s-DS-project/blob/main/Alzheimers_DS_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("alzheimers_disease_data.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 df=pd.read_csv("alzheimers_disease_data.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df.isnull().sum()
# Out:
# PatientID                    0
# Age                          0
# Gender                       0
# Ethnicity                    0
# EducationLevel               0
# BMI                          0
# Smoking                      0
# AlcoholConsumption           0
# PhysicalActivity             0
# DietQuality                  0
# SleepQuality                 0
# FamilyHistoryAlzheimers      0
# CardiovascularDisease        0
# Diabetes                     0
# Depression                   0
# HeadInjury                   0
# Hypertension                 0
# SystolicBP                   0
# DiastolicBP                  0
# CholesterolTotal             0
# CholesterolLDL               0
# CholesterolHDL               0
# CholesterolTriglycerides     0
# MMSE                         0
# FunctionalAssessment         0
# MemoryComplaints             0
# BehavioralProblems           0
# ADL                          0
# Confusion                    0
# Disorientation               0
# ...

# %%
df.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease',
#        'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment',
#        'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion',
#        'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks',
#        'Forgetfulness', 'Diagnosis', 'DoctorInCharge'],
#       dtype='object')

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
#correlation
x = df.corr(numeric_only=True)
print(x)
# Out:
#                            PatientID       Age    Gender  Ethnicity  \
# PatientID                   1.000000  0.002947 -0.043665  -0.007608
# Age                         0.002947  1.000000  0.028708   0.027745
# Gender                     -0.043665  0.028708  1.000000  -0.003660
# Ethnicity                  -0.007608  0.027745 -0.003660   1.000000
# EducationLevel             -0.001729 -0.060560 -0.007070   0.026516
# BMI                        -0.034228 -0.015677  0.005928  -0.003176
# Smoking                     0.021907  0.020060  0.016650   0.031485
# AlcoholConsumption         -0.020733  0.007323  0.004330   0.008363
# PhysicalActivity           -0.011424 -0.010249 -0.035795   0.020498
# DietQuality                -0.018490 -0.023386  0.010942  -0.018184
# SleepQuality               -0.026069  0.049139  0.007310   0.029304
# FamilyHistoryAlzheimers     0.002187 -0.018784  0.018421   0.022526
# CardiovascularDisease       0.017675 -0.015284  0.034577   0.002347
# ...

# %%
#how to remove null values/outlier
new_df=df.fillna("")
new_df
# Out:
#       PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0          4751   73       0          0               2  22.927749        0
# 1          4752   89       0          0               0  26.827681        0
# 2          4753   73       0          3               1  17.795882        0
# 3          4754   74       1          0               1  33.800817        1
# 4          4755   89       0          0               0  20.716974        0
# ...         ...  ...     ...        ...             ...        ...      ...
# 2144       6895   61       0          0               1  39.121757        0
# 2145       6896   75       0          0               2  17.857903        0
# 2146       6897   77       0          0               1  15.476479        0
# 2147       6898   78       1          3               1  15.299911        0
# 2148       6899   72       0          0               2  33.289738        0
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe().T
# Out:
#                             count         mean         std          min  \
# PatientID                  2149.0  5825.000000  620.507185  4751.000000
# Age                        2149.0    74.908795    8.990221    60.000000
# Gender                     2149.0     0.506282    0.500077     0.000000
# Ethnicity                  2149.0     0.697534    0.996128     0.000000
# EducationLevel             2149.0     1.286645    0.904527     0.000000
# BMI                        2149.0    27.655697    7.217438    15.008851
# Smoking                    2149.0     0.288506    0.453173     0.000000
# AlcoholConsumption         2149.0    10.039442    5.757910     0.002003
# PhysicalActivity           2149.0     4.920202    2.857191     0.003616
# DietQuality                2149.0     4.993138    2.909055     0.009385
# SleepQuality               2149.0     7.051081    1.763573     4.002629
# FamilyHistoryAlzheimers    2149.0     0.252210    0.434382     0.000000
# ...

# %%
df.describe().T.plot(kind = 'line', y = 'std', marker = 'o', linestyle = "-", figsize = (15,4))
plt.title("Standard Deviation");

# %%
categorical_columns = ['Gender','Ethnicity','Diagnosis','DoctorInCharge']
categorical_columns
# Out:
# ['Gender', 'Ethnicity', 'Diagnosis', 'DoctorInCharge']

# %%
numerical_columns = ['Age', 'BMI', 'AlcoholConsumption', 'PhysicalActivity','SystolicBP', 'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL', 'CholesterolTriglycerides', 'MMSE']
numerical_columns
# Out:
# ['Age',
#  'BMI',
#  'AlcoholConsumption',
#  'PhysicalActivity',
#  'SystolicBP',
#  'DiastolicBP',
#  'CholesterolTotal',
#  'CholesterolLDL',
#  'CholesterolHDL',
#  'CholesterolTriglycerides',
#  'MMSE']

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
numeric_columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'AlcoholConsumption', 'PhysicalActivity', 'DietQuality',
#        'SleepQuality', 'FamilyHistoryAlzheimers', 'CardiovascularDisease',
#        'Diabetes', 'Depression', 'HeadInjury', 'Hypertension', 'SystolicBP',
#        'DiastolicBP', 'CholesterolTotal', 'CholesterolLDL', 'CholesterolHDL',
#        'CholesterolTriglycerides', 'MMSE', 'FunctionalAssessment',
#        'MemoryComplaints', 'BehavioralProblems', 'ADL', 'Confusion',
#        'Disorientation', 'PersonalityChanges', 'DifficultyCompletingTasks',
#        'Forgetfulness', 'Diagnosis'],
#       dtype='object')

# %%
Q1 = df[numeric_columns].quantile(0.25)
Q3 = df[numeric_columns].quantile(0.75)
IQR = Q3 - Q1

outliers = ((df[numeric_columns] < (Q1 - 1.5*IQR)) | (df[numeric_columns] > (Q3 + 1.5*IQR)))
outliers_count = outliers.sum()
print(f'Outliers counts: {outliers_count}')
# Out:
# Outliers counts: PatientID                      0
# Age                            0
# Gender                         0
# Ethnicity                    211
# EducationLevel                 0
# BMI                            0
# Smoking                        0
# AlcoholConsumption             0
# PhysicalActivity               0
# DietQuality                    0
# SleepQuality                   0
# FamilyHistoryAlzheimers        0
# CardiovascularDisease        310
# Diabetes                     324
# Depression                   431
# HeadInjury                   199
# Hypertension                 320
# SystolicBP                     0
# DiastolicBP                    0
# CholesterolTotal               0
# CholesterolLDL                 0
# CholesterolHDL                 0
# CholesterolTriglycerides       0
# MMSE                           0
# FunctionalAssessment           0
# MemoryComplaints             447
# BehavioralProblems           337
# ADL                            0
# ...

# %%
plt.figure(figsize=(14, 6))
plt.boxplot(df[numerical_columns])
plt.title("Box plot of numerical columns")
plt.xlabel('Columns')
plt.ylabel('Values')
plt.show()

# %%
#EDA
df['Diagnosis'].value_counts()
# Out:
# Diagnosis
# 0    1389
# 1     760
# Name: count, dtype: int64

# %%
plt.hist(df['Age'], bins = 10, color='purple', edgecolor = 'black')
# Out:
# (array([212., 192., 234., 217., 203., 217., 197., 196., 178., 303.]),
#  array([60., 63., 66., 69., 72., 75., 78., 81., 84., 87., 90.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot([df[df['Diagnosis'] == 0]['BMI'], df[df['Diagnosis'] == 1]['BMI']],showmeans=True, meanline= True,labels= ['Non-Alzheimer', 'Alzheimer'])
plt.title('BMI Distribution by Diagnosis')
plt.ylabel('BMI');
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2676\1554188474.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[df['Diagnosis'] == 0]['BMI'], df[df['Diagnosis'] == 1]['BMI']],showmeans=True, meanline= True,labels= ['Non-Alzheimer', 'Alzheimer'])

# %%
df['Depression'].value_counts()
# Out:
# Depression
# 0    1718
# 1     431
# Name: count, dtype: int64

# %%
import seaborn as sns
ab = sns.countplot(df, x = 'Depression', hue = 'Diagnosis')

for a in ab.patches:
    ab.annotate(f'{a.get_height()}',
                (a.get_x() + a.get_width() / 2., a.get_height()),
                ha='center', va='center',
                fontsize=14, color='black',
                xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
df['Diagnosis'].groupby(df['FamilyHistoryAlzheimers']).sum()
# Out:
# FamilyHistoryAlzheimers
# 0    583
# 1    177
# Name: Diagnosis, dtype: int64

# %%
af = sns.countplot(df, x = 'FamilyHistoryAlzheimers', hue = 'Diagnosis')

for a in af.patches:
    af.annotate(f'{a.get_height()}',
                (a.get_x() + a.get_width() / 2., a.get_height()),
                ha='center', va='center',
                fontsize=14, color='black',
                xytext=(0, 5),
                textcoords='offset points')

plt.show()

# %%
plt.subplots(1,1)
sns.histplot(df[df['Diagnosis'] == 0]['SystolicBP'], kde =True, color = 'green', label = 'Non-Alzheime')
plt.subplots(1,1)
sns.histplot(df[df['Diagnosis'] == 1]['SystolicBP'], kde =True, color = 'red', label = 'Alzheime')
# Out:
# <Axes: xlabel='SystolicBP', ylabel='Count'>

# %%
memory_complaints_counts = df.groupby('Diagnosis')['MemoryComplaints'].sum()
plt.bar(['Non-Alzheimer', 'Alzheimer'], memory_complaints_counts, color=['green', 'red'])
# Out:
# <BarContainer object of 2 artists>

# %%
df.groupby(['EducationLevel', 'Diagnosis']).size().reset_index(name='Count')
# Out:
#    EducationLevel  Diagnosis  Count
# 0               0          0    272
# 1               0          1    174
# 2               1          0    552
# 3               1          1    302
# 4               2          0    419
# 5               2          1    217
# 6               3          0    146
# 7               3          1     67

# %%
sns.heatmap(x, annot=True)
# Out:
# <Axes: >
